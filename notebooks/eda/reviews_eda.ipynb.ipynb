# %%
import logging

# Disable debug logging to prevent verbose thread monitor output
logging.getLogger().setLevel(logging.ERROR)
logging.getLogger('ThreadMonitor').setLevel(logging.ERROR)

# %%
# Configure AWS credentials for S3 access
spark.conf.set("fs.s3a.access.key", "ASIAXXXXX")
spark.conf.set("fs.s3a.secret.key", "XXXXXXXX/XXXX/XXXX")
spark.conf.set("fs.s3a.session.token", "...")
spark.conf.set("fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.TemporaryAWSCredentialsProvider")
spark.conf.set("fs.s3a.endpoint", "s3.amazonaws.com")

# %%
reviews_df = (
    spark.read
    .format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .option("multiLine", "true")        # CRITICAL
    .option("quote", "\"")              # handle quoted text
    .option("escape", "\"")             # handle escaped quotes
    .option("mode", "PERMISSIVE")       # don't break on bad rows
    .option("encoding", "UTF-8")
    .load("s3://steam-dataset-2025-bucket/Steam/steam_dataset_2025_csv_package_v1/steam_dataset_2025_csv/reviews.csv")
)

# %%
display(reviews_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>recommendationid</th><th>appid</th><th>author_steamid</th><th>author_num_games_owned</th><th>author_num_reviews</th><th>author_playtime_forever</th><th>author_playtime_last_two_weeks</th><th>author_playtime_at_review</th><th>author_last_played</th><th>language</th><th>review_text</th><th>timestamp_created</th><th>timestamp_updated</th><th>voted_up</th><th>votes_up</th><th>votes_funny</th><th>weighted_vote_score</th><th>comment_count</th><th>steam_purchase</th><th>received_for_free</th><th>written_during_early_access</th><th>created_at</th><th>updated_at</th></tr></thead><tbody><tr><td>10000000</td><td>264220</td><td>76561198085405844</td><td>760</td><td>74</td><td>12.0</td><td>0.0</td><td>12.0</td><td>1.399059573E9</td><td>polish</td><td>What's a crap. This game costs 2 euro but is worth less than 0.1 cent. It has full of bugs, is slowly, not dynamic. It's crashed under my windows xp, so I installed on win8.1, it's crashed too. Please test it before you release.</td><td>1399059965</td><td>1399059965</td><td>true</td><td>0</td><td>1</td><td>0.45990565</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100001066</td><td>1006440</td><td>76561198014439859</td><td>485</td><td>234</td><td>424.0</td><td>0.0</td><td>424.0</td><td>1.632666417E9</td><td>russian</td><td>Игра в жанре квеста point-&-click, но особенность в том, что вся игра отснята с живыми актёрами в реальном окружении. Вы частный детектив и в один из обычных рутинных дней к вам приходит дама с просьбой. И понеслось. Мотаешься по всему городу, общаешься с людьми, добываешь информацию и всё в заранее отснятых сценах. Где-то более часа чистого видео материала на все ваше действия, правильные и ошибочные.</td><td>1632673992</td><td>1632673992</td><td>true</td><td>8</td><td>0</td><td>0.63077044</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100002344</td><td>320721</td><td>76561198048038590</td><td>0</td><td>385</td><td>0.0</td><td>0.0</td><td>null</td><td>0.0</td><td>german</td><td>Erneut gibt es einen DLC mit drei neuen Lords die sich nur maginal von den anderen unterscheiden. Für (momentan) fünf Euro finde ich das persönlich etwas zu viel.</td><td>1632675631</td><td>1632675631</td><td>false</td><td>1</td><td>0</td><td>0.52380955</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100002361</td><td>1604700</td><td>76561197994386273</td><td>0</td><td>3</td><td>86.0</td><td>0.0</td><td>86.0</td><td>1.632674318E9</td><td>english</td><td>It took me a grueling 18 months, but I built a catalog of more than 30 highly-regarded books and raised our average first print revenue to nearly a million dollars.
#
# A completely authentic publishing sim.</td><td>1632675648</td><td>1632680067</td><td>true</td><td>3</td><td>0</td><td>0.54198474</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100002504</td><td>1338560</td><td>76561198138996331</td><td>816</td><td>26</td><td>25.0</td><td>0.0</td><td>25.0</td><td>1.632639242E9</td><td>english</td><td>incredibly simple game. it does get boring quite quickly and there isn't much to do in this game. it's not really worth $1 though. It's a good game to have playing in the background while you study though.
#
# Cats also enjoy watching the bees fly around your screen. 10/10 for that.</td><td>1632675819</td><td>1632675819</td><td>true</td><td>1</td><td>0</td><td>0.52380955</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100002591</td><td>1418320</td><td>76561199208288640</td><td>0</td><td>1</td><td>60.0</td><td>0.0</td><td>60.0</td><td>1.631962286E9</td><td>spanish</td><td>Un juego entretenido que he regalado a mis sobrinos de 10 y 12 años  y les ha encantado. Un mundo, el del Siglo de Oro español, desconocido para ellos, que ha permitido que al menos me hagan algunas preguntas sobre Don Quijote.</td><td>1632675927</td><td>1632675927</td><td>true</td><td>2</td><td>0</td><td>0.54545456</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100003580</td><td>1232500</td><td>76561199089236340</td><td>0</td><td>2</td><td>311.0</td><td>0.0</td><td>261.0</td><td>1.728524073E9</td><td>japanese</td><td>一言で言うと2か所のチェックポイントを通過し、ゴールを目指すゲーム。
# なんでライフルを持ってるのって？山は危険だからね護身武器は必要だよね（棒読み）
#
# 高難度の方までクリアしましたが、慎重に進めば時間はかかりますけど
# やられることはないと思います。リンが回復してくれますし。
# 敵は奥から来るだけでなく崖の上にいることもあるので注意。
#
# ハイキングってなんだ（哲学）
# 自分は割と楽しんだのでおすすめしておきます。</td><td>1632677169</td><td>1632677169</td><td>true</td><td>2</td><td>0</td><td>0.54038996</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100003676</td><td>726870</td><td>76561198155272674</td><td>0</td><td>13</td><td>639.0</td><td>0.0</td><td>188.0</td><td>1.632773037E9</td><td>english</td><td>If you enjoy text-based games, this is a must buy -- particularly if you like horror, sleuthing, and/or the Cthulhu mythos.
#
# For older gamers, note that this game is as good as (and in some respects even better than) many classic Infocom interactive fiction titles.</td><td>1632677314</td><td>1639239547</td><td>true</td><td>0</td><td>0</td><td>0.5</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100003804</td><td>1721670</td><td>76561198056175175</td><td>315</td><td>14</td><td>0.0</td><td>0.0</td><td>null</td><td>0.0</td><td>english</td><td>very cool.</td><td>1632677489</td><td>1632677489</td><td>true</td><td>0</td><td>0</td><td>0.5</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr><tr><td>100005000</td><td>1638870</td><td>76561199059802534</td><td>0</td><td>4</td><td>12.0</td><td>0.0</td><td>12.0</td><td>1.630245355E9</td><td>russian</td><td>ДИЧЬ
# </td><td>1632678961</td><td>1632678961</td><td>false</td><td>0</td><td>0</td><td>0.5</td><td>0</td><td>true</td><td>false</td><td>false</td><td>2025-09-07T12:51:00.564782Z</td><td>2025-09-08T00:47:55.754043Z</td></tr></tbody></table></div>

# %%
reviews_df.printSchema()
# Out:
# root
#  |-- recommendationid: integer (nullable = true)
#  |-- appid: integer (nullable = true)
#  |-- author_steamid: long (nullable = true)
#  |-- author_num_games_owned: integer (nullable = true)
#  |-- author_num_reviews: integer (nullable = true)
#  |-- author_playtime_forever: double (nullable = true)
#  |-- author_playtime_last_two_weeks: double (nullable = true)
#  |-- author_playtime_at_review: double (nullable = true)
#  |-- author_last_played: double (nullable = true)
#  |-- language: string (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- timestamp_created: integer (nullable = true)
#  |-- timestamp_updated: integer (nullable = true)
#  |-- voted_up: boolean (nullable = true)
#  |-- votes_up: integer (nullable = true)
#  |-- votes_funny: long (nullable = true)
#  |-- weighted_vote_score: double (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- steam_purchase: boolean (nullable = true)
#  |-- received_for_free: boolean (nullable = true)
#  |-- written_during_early_access: boolean (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- updated_at: timestamp (nullable = true)

# %%
display(
    reviews_df.select(
        "recommendationid",
        "appid",
        "review_text",
        "votes_up",
        "language"
    ).limit(10)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>recommendationid</th><th>appid</th><th>review_text</th><th>votes_up</th><th>language</th></tr></thead><tbody><tr><td>10000000</td><td>264220</td><td>What's a crap. This game costs 2 euro but is worth less than 0.1 cent. It has full of bugs, is slowly, not dynamic. It's crashed under my windows xp, so I installed on win8.1, it's crashed too. Please test it before you release.</td><td>0</td><td>polish</td></tr><tr><td>100001066</td><td>1006440</td><td>Игра в жанре квеста point-&-click, но особенность в том, что вся игра отснята с живыми актёрами в реальном окружении. Вы частный детектив и в один из обычных рутинных дней к вам приходит дама с просьбой. И понеслось. Мотаешься по всему городу, общаешься с людьми, добываешь информацию и всё в заранее отснятых сценах. Где-то более часа чистого видео материала на все ваше действия, правильные и ошибочные.</td><td>8</td><td>russian</td></tr><tr><td>100002344</td><td>320721</td><td>Erneut gibt es einen DLC mit drei neuen Lords die sich nur maginal von den anderen unterscheiden. Für (momentan) fünf Euro finde ich das persönlich etwas zu viel.</td><td>1</td><td>german</td></tr><tr><td>100002361</td><td>1604700</td><td>It took me a grueling 18 months, but I built a catalog of more than 30 highly-regarded books and raised our average first print revenue to nearly a million dollars.
#
# A completely authentic publishing sim.</td><td>3</td><td>english</td></tr><tr><td>100002504</td><td>1338560</td><td>incredibly simple game. it does get boring quite quickly and there isn't much to do in this game. it's not really worth $1 though. It's a good game to have playing in the background while you study though.
#
# Cats also enjoy watching the bees fly around your screen. 10/10 for that.</td><td>1</td><td>english</td></tr><tr><td>100002591</td><td>1418320</td><td>Un juego entretenido que he regalado a mis sobrinos de 10 y 12 años  y les ha encantado. Un mundo, el del Siglo de Oro español, desconocido para ellos, que ha permitido que al menos me hagan algunas preguntas sobre Don Quijote.</td><td>2</td><td>spanish</td></tr><tr><td>100003580</td><td>1232500</td><td>一言で言うと2か所のチェックポイントを通過し、ゴールを目指すゲーム。
# なんでライフルを持ってるのって？山は危険だからね護身武器は必要だよね（棒読み）
#
# 高難度の方までクリアしましたが、慎重に進めば時間はかかりますけど
# やられることはないと思います。リンが回復してくれますし。
# 敵は奥から来るだけでなく崖の上にいることもあるので注意。
#
# ハイキングってなんだ（哲学）
# 自分は割と楽しんだのでおすすめしておきます。</td><td>2</td><td>japanese</td></tr><tr><td>100003676</td><td>726870</td><td>If you enjoy text-based games, this is a must buy -- particularly if you like horror, sleuthing, and/or the Cthulhu mythos.
#
# For older gamers, note that this game is as good as (and in some respects even better than) many classic Infocom interactive fiction titles.</td><td>0</td><td>english</td></tr><tr><td>100003804</td><td>1721670</td><td>very cool.</td><td>0</td><td>english</td></tr><tr><td>100005000</td><td>1638870</td><td>ДИЧЬ
# </td><td>0</td><td>russian</td></tr></tbody></table></div>

# %%
print(reviews_df.count())
# Out:
# 1048148

# %%
bi_reviews_df = reviews_df.select(
    "appid",
    "recommendationid",
    "votes_up",
    "votes_funny",
    "comment_count",
    "weighted_vote_score",
    "author_playtime_at_review",
    "author_playtime_forever",
    "author_playtime_last_two_weeks",
    "author_num_games_owned",
    "author_num_reviews",
    "steam_purchase",
    "received_for_free",
    "written_during_early_access",
    "language",
    "timestamp_created"
)

# %%
bi_reviews_df.printSchema()
# Out:
# root
#  |-- appid: integer (nullable = true)
#  |-- recommendationid: integer (nullable = true)
#  |-- votes_up: integer (nullable = true)
#  |-- votes_funny: long (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- weighted_vote_score: double (nullable = true)
#  |-- author_playtime_at_review: double (nullable = true)
#  |-- author_playtime_forever: double (nullable = true)
#  |-- author_playtime_last_two_weeks: double (nullable = true)
#  |-- author_num_games_owned: integer (nullable = true)
#  |-- author_num_reviews: integer (nullable = true)
#  |-- steam_purchase: boolean (nullable = true)
#  |-- received_for_free: boolean (nullable = true)
#  |-- written_during_early_access: boolean (nullable = true)
#  |-- language: string (nullable = true)
#  |-- timestamp_created: integer (nullable = true)

# %%
display(bi_reviews_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appid</th><th>recommendationid</th><th>votes_up</th><th>votes_funny</th><th>comment_count</th><th>weighted_vote_score</th><th>author_playtime_at_review</th><th>author_playtime_forever</th><th>author_playtime_last_two_weeks</th><th>author_num_games_owned</th><th>author_num_reviews</th><th>steam_purchase</th><th>received_for_free</th><th>written_during_early_access</th><th>language</th><th>timestamp_created</th></tr></thead><tbody><tr><td>264220</td><td>10000000</td><td>0</td><td>1</td><td>0</td><td>0.45990565</td><td>12.0</td><td>12.0</td><td>0.0</td><td>760</td><td>74</td><td>true</td><td>false</td><td>false</td><td>polish</td><td>1399059965</td></tr><tr><td>1006440</td><td>100001066</td><td>8</td><td>0</td><td>0</td><td>0.63077044</td><td>424.0</td><td>424.0</td><td>0.0</td><td>485</td><td>234</td><td>true</td><td>false</td><td>false</td><td>russian</td><td>1632673992</td></tr><tr><td>320721</td><td>100002344</td><td>1</td><td>0</td><td>0</td><td>0.52380955</td><td>null</td><td>0.0</td><td>0.0</td><td>0</td><td>385</td><td>true</td><td>false</td><td>false</td><td>german</td><td>1632675631</td></tr><tr><td>1604700</td><td>100002361</td><td>3</td><td>0</td><td>0</td><td>0.54198474</td><td>86.0</td><td>86.0</td><td>0.0</td><td>0</td><td>3</td><td>true</td><td>false</td><td>false</td><td>english</td><td>1632675648</td></tr><tr><td>1338560</td><td>100002504</td><td>1</td><td>0</td><td>0</td><td>0.52380955</td><td>25.0</td><td>25.0</td><td>0.0</td><td>816</td><td>26</td><td>true</td><td>false</td><td>false</td><td>english</td><td>1632675819</td></tr><tr><td>1418320</td><td>100002591</td><td>2</td><td>0</td><td>0</td><td>0.54545456</td><td>60.0</td><td>60.0</td><td>0.0</td><td>0</td><td>1</td><td>true</td><td>false</td><td>false</td><td>spanish</td><td>1632675927</td></tr><tr><td>1232500</td><td>100003580</td><td>2</td><td>0</td><td>0</td><td>0.54038996</td><td>261.0</td><td>311.0</td><td>0.0</td><td>0</td><td>2</td><td>true</td><td>false</td><td>false</td><td>japanese</td><td>1632677169</td></tr><tr><td>726870</td><td>100003676</td><td>0</td><td>0</td><td>0</td><td>0.5</td><td>188.0</td><td>639.0</td><td>0.0</td><td>0</td><td>13</td><td>true</td><td>false</td><td>false</td><td>english</td><td>1632677314</td></tr><tr><td>1721670</td><td>100003804</td><td>0</td><td>0</td><td>0</td><td>0.5</td><td>null</td><td>0.0</td><td>0.0</td><td>315</td><td>14</td><td>true</td><td>false</td><td>false</td><td>english</td><td>1632677489</td></tr><tr><td>1638870</td><td>100005000</td><td>0</td><td>0</td><td>0</td><td>0.5</td><td>12.0</td><td>12.0</td><td>0.0</td><td>0</td><td>4</td><td>true</td><td>false</td><td>false</td><td>russian</td><td>1632678961</td></tr></tbody></table></div>

# %%
total_rows = bi_reviews_df.count()
total_rows
# Out:
# 1048148

# %%
from pyspark.sql.functions import col, count, when

null_summary = bi_reviews_df.select([
    count(when(col(c).isNull(), c)).alias(c)
    for c in bi_reviews_df.columns
])

display(null_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appid</th><th>recommendationid</th><th>votes_up</th><th>votes_funny</th><th>comment_count</th><th>weighted_vote_score</th><th>author_playtime_at_review</th><th>author_playtime_forever</th><th>author_playtime_last_two_weeks</th><th>author_num_games_owned</th><th>author_num_reviews</th><th>steam_purchase</th><th>received_for_free</th><th>written_during_early_access</th><th>language</th><th>timestamp_created</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>178857</td><td>3</td><td>3</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
null_percentage = bi_reviews_df.select([
    (count(when(col(c).isNull(), c)) / total_rows * 100).alias(c)
    for c in bi_reviews_df.columns
])

display(null_percentage)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appid</th><th>recommendationid</th><th>votes_up</th><th>votes_funny</th><th>comment_count</th><th>weighted_vote_score</th><th>author_playtime_at_review</th><th>author_playtime_forever</th><th>author_playtime_last_two_weeks</th><th>author_num_games_owned</th><th>author_num_reviews</th><th>steam_purchase</th><th>received_for_free</th><th>written_during_early_access</th><th>language</th><th>timestamp_created</th></tr></thead><tbody><tr><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>17.064097818247042</td><td>2.8621912172708435E-4</td><td>2.8621912172708435E-4</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr></tbody></table></div>

# %%
zero_summary = bi_reviews_df.select([
    count(when(col(c) == 0, c)).alias(c)
    for c in [
        "votes_up",
        "votes_funny",
        "comment_count",
        "author_playtime_at_review",
        "author_playtime_last_two_weeks",
        "author_num_games_owned",
        "author_num_reviews"
    ]
])

display(zero_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>votes_up</th><th>votes_funny</th><th>comment_count</th><th>author_playtime_at_review</th><th>author_playtime_last_two_weeks</th><th>author_num_games_owned</th><th>author_num_reviews</th></tr></thead><tbody><tr><td>482203</td><td>870011</td><td>979432</td><td>0</td><td>857503</td><td>545274</td><td>0</td></tr></tbody></table></div>

# %%
quantiles = bi_reviews_df.select(
    "author_playtime_forever",
    "author_playtime_at_review",
    "author_playtime_last_two_weeks",
    "votes_up",
    "votes_funny",
    "comment_count"
).summary("min", "50%", "90%", "95%", "99%", "max")

display(quantiles)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>author_playtime_forever</th><th>author_playtime_at_review</th><th>author_playtime_last_two_weeks</th><th>votes_up</th><th>votes_funny</th><th>comment_count</th></tr></thead><tbody><tr><td>min</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>50%</td><td>163.0</td><td>194.0</td><td>0.0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>90%</td><td>2422.0</td><td>2156.0</td><td>237.0</td><td>8</td><td>1</td><td>0</td></tr><tr><td>95%</td><td>5142.0</td><td>4543.0</td><td>732.0</td><td>14</td><td>2</td><td>1</td></tr><tr><td>99%</td><td>26026.0</td><td>22677.0</td><td>2673.0</td><td>49</td><td>10</td><td>4</td></tr><tr><td>max</td><td>4309938.0</td><td>2030768.0</td><td>20144.0</td><td>8270</td><td>4294967295</td><td>666</td></tr></tbody></table></div>

# %%
caps = bi_reviews_df.approxQuantile(
    [
        "author_playtime_forever",
        "author_playtime_at_review",
        "author_playtime_last_two_weeks",
        "votes_up",
        "votes_funny",
        "comment_count"
    ],
    [0.99],
    0.01
)

caps
# Out:
# [[4309938.0], [2030768.0], [20144.0], [8270.0], [4294967295.0], [666.0]]

# %%
from pyspark.sql.functions import when, col

bi_reviews_capped_df = (
    bi_reviews_df
    # Playtime caps
    .withColumn(
        "author_playtime_forever_capped",
        when(col("author_playtime_forever") > 26026, 26026)
        .otherwise(col("author_playtime_forever"))
    )
    .withColumn(
        "author_playtime_at_review_capped",
        when(col("author_playtime_at_review") > 22677, 22677)
        .otherwise(col("author_playtime_at_review"))
    )
    .withColumn(
        "author_playtime_last_two_weeks_capped",
        when(col("author_playtime_last_two_weeks") > 2673, 2673)
        .otherwise(col("author_playtime_last_two_weeks"))
    )
    # Engagement caps
    .withColumn(
        "votes_up_capped",
        when(col("votes_up") > 49, 49)
        .otherwise(col("votes_up"))
    )
    .withColumn(
        "votes_funny_capped",
        when(col("votes_funny") > 10, 10)
        .otherwise(col("votes_funny"))
    )
    .withColumn(
        "comment_count_capped",
        when(col("comment_count") > 4, 4)
        .otherwise(col("comment_count"))
    )
)

# %%
display(
    bi_reviews_capped_df.select(
        "author_playtime_forever",
        "author_playtime_forever_capped",
        "votes_funny",
        "votes_funny_capped",
        "comment_count",
        "comment_count_capped"
    ).limit(20)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>author_playtime_forever</th><th>author_playtime_forever_capped</th><th>votes_funny</th><th>votes_funny_capped</th><th>comment_count</th><th>comment_count_capped</th></tr></thead><tbody><tr><td>12.0</td><td>12.0</td><td>1</td><td>1</td><td>0</td><td>0</td></tr><tr><td>424.0</td><td>424.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>0.0</td><td>0.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>86.0</td><td>86.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>25.0</td><td>25.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>60.0</td><td>60.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>311.0</td><td>311.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>639.0</td><td>639.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>0.0</td><td>0.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>12.0</td><td>12.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>919.0</td><td>919.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>53.0</td><td>53.0</td><td>0</td><td>0</td><td>1</td><td>1</td></tr><tr><td>1299.0</td><td>1299.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>0.0</td><td>0.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>100.0</td><td>100.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>261.0</td><td>261.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>130.0</td><td>130.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>52.0</td><td>52.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>0.0</td><td>0.0</td><td>5</td><td>5</td><td>0</td><td>0</td></tr><tr><td>7.0</td><td>7.0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import max

display(
    bi_reviews_capped_df.select(max("author_playtime_forever_capped").alias("max_author_playtime_forever"))
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max_author_playtime_forever</th></tr></thead><tbody><tr><td>26026.0</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import (
    from_unixtime,
    to_date,
    year,
    month,
    date_format
)

bi_reviews_time_df = (
    bi_reviews_capped_df
    # Convert unix timestamp → timestamp
    .withColumn(
        "review_timestamp",
        from_unixtime(col("timestamp_created"))
    )
    # Date column
    .withColumn(
        "review_date",
        to_date(col("review_timestamp"))
    )
    # Time dimensions
    .withColumn(
        "review_year",
        year(col("review_timestamp"))
    )
    .withColumn(
        "review_month",
        month(col("review_timestamp"))
    )
    .withColumn(
        "review_year_month",
        date_format(col("review_timestamp"), "yyyy-MM")
    )
)

# %%
display(
    bi_reviews_time_df.select(
        "timestamp_created",
        "review_timestamp",
        "review_date",
        "review_year",
        "review_month",
        "review_year_month"
    ).limit(10)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp_created</th><th>review_timestamp</th><th>review_date</th><th>review_year</th><th>review_month</th><th>review_year_month</th></tr></thead><tbody><tr><td>1399059965</td><td>2014-05-02 19:46:05</td><td>2014-05-02</td><td>2014</td><td>5</td><td>2014-05</td></tr><tr><td>1632673992</td><td>2021-09-26 16:33:12</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr><tr><td>1632675631</td><td>2021-09-26 17:00:31</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr><tr><td>1632675648</td><td>2021-09-26 17:00:48</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr><tr><td>1632675819</td><td>2021-09-26 17:03:39</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr><tr><td>1632675927</td><td>2021-09-26 17:05:27</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr><tr><td>1632677169</td><td>2021-09-26 17:26:09</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr><tr><td>1632677314</td><td>2021-09-26 17:28:34</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr><tr><td>1632677489</td><td>2021-09-26 17:31:29</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr><tr><td>1632678961</td><td>2021-09-26 17:56:01</td><td>2021-09-26</td><td>2021</td><td>9</td><td>2021-09</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import (
    count,
    avg,
    sum as spark_sum
)

app_review_agg_df = (
    bi_reviews_time_df
    .groupBy("appid")
    .agg(
        count("*").alias("total_reviews"),

        avg("votes_up_capped").alias("avg_votes_up"),
        avg("votes_funny_capped").alias("avg_votes_funny"),
        avg("comment_count_capped").alias("avg_comment_count"),
        avg("weighted_vote_score").alias("avg_weighted_vote_score"),

        avg("author_playtime_forever_capped").alias("avg_playtime_forever"),

        (spark_sum(col("steam_purchase").cast("int")) / count("*")).alias("pct_steam_purchase"),
        (spark_sum(col("received_for_free").cast("int")) / count("*")).alias("pct_received_for_free"),
        (spark_sum(col("written_during_early_access").cast("int")) / count("*")).alias("pct_early_access")
    )
)

# %%
display(app_review_agg_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appid</th><th>total_reviews</th><th>avg_votes_up</th><th>avg_votes_funny</th><th>avg_comment_count</th><th>avg_weighted_vote_score</th><th>avg_playtime_forever</th><th>pct_steam_purchase</th><th>pct_received_for_free</th><th>pct_early_access</th></tr></thead><tbody><tr><td>1362650</td><td>17</td><td>1.1764705882352942</td><td>0.0</td><td>0.058823529411764705</td><td>0.5073456358823529</td><td>149.1764705882353</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>525640</td><td>100</td><td>5.26</td><td>0.23</td><td>0.22</td><td>0.5514197209000001</td><td>2874.67</td><td>1.0</td><td>0.01</td><td>0.74</td></tr><tr><td>962300</td><td>4</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.4953703725</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>617580</td><td>9</td><td>2.0</td><td>0.0</td><td>0.1111111111111111</td><td>0.5171290133333334</td><td>3744.6666666666665</td><td>1.0</td><td>0.1111111111111111</td><td>0.0</td></tr><tr><td>1633470</td><td>4</td><td>2.75</td><td>0.25</td><td>0.5</td><td>0.553060665</td><td>60.5</td><td>1.0</td><td>0.25</td><td>0.0</td></tr><tr><td>1283960</td><td>100</td><td>2.84</td><td>0.3</td><td>0.09</td><td>0.5295989410999999</td><td>3048.88</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>323250</td><td>19</td><td>2.473684210526316</td><td>0.05263157894736842</td><td>0.0</td><td>0.52567672</td><td>4379.9473684210525</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>265240</td><td>21</td><td>7.714285714285714</td><td>0.0</td><td>0.0</td><td>0.5353623980952382</td><td>319.8095238095238</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>934920</td><td>6</td><td>2.1666666666666665</td><td>0.0</td><td>0.0</td><td>0.5470834466666666</td><td>5134.833333333333</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1097120</td><td>13</td><td>6.846153846153846</td><td>1.0769230769230769</td><td>0.0</td><td>0.5363296376923076</td><td>19.846153846153847</td><td>1.0</td><td>0.07692307692307693</td><td>0.0</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import count, avg, sum as spark_sum

app_month_review_agg_df = (
    bi_reviews_time_df
    .groupBy("appid", "review_year_month")
    .agg(
        count("*").alias("monthly_reviews"),

        avg("votes_up_capped").alias("avg_votes_up"),
        avg("votes_funny_capped").alias("avg_votes_funny"),
        avg("comment_count_capped").alias("avg_comment_count"),
        avg("weighted_vote_score").alias("avg_weighted_vote_score"),

        avg("author_playtime_forever_capped").alias("avg_playtime_forever"),

        (spark_sum(col("steam_purchase").cast("int")) / count("*")).alias("pct_steam_purchase"),
        (spark_sum(col("received_for_free").cast("int")) / count("*")).alias("pct_received_for_free"),
        (spark_sum(col("written_during_early_access").cast("int")) / count("*")).alias("pct_early_access")
    )
)

# %%
display(
    app_month_review_agg_df
    .orderBy("appid", "review_year_month")
    .limit(20)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appid</th><th>review_year_month</th><th>monthly_reviews</th><th>avg_votes_up</th><th>avg_votes_funny</th><th>avg_comment_count</th><th>avg_weighted_vote_score</th><th>avg_playtime_forever</th><th>pct_steam_purchase</th><th>pct_received_for_free</th><th>pct_early_access</th></tr></thead><tbody><tr><td>400</td><td>2025-08</td><td>100</td><td>1.0</td><td>0.16</td><td>0.12</td><td>0.5126717692</td><td>585.34</td><td>1.0</td><td>0.02</td><td>0.0</td></tr><tr><td>1280</td><td>2025-08</td><td>20</td><td>0.55</td><td>0.05</td><td>0.1</td><td>0.503991207</td><td>4069.45</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1300</td><td>2025-08</td><td>19</td><td>0.9473684210526315</td><td>0.05263157894736842</td><td>0.2631578947368421</td><td>0.5127347836842105</td><td>213.26315789473685</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1313</td><td>2025-08</td><td>6</td><td>1.6666666666666667</td><td>0.0</td><td>0.0</td><td>0.5171330566666668</td><td>582.3333333333334</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1500</td><td>2025-08</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>589.5</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1510</td><td>2025-08</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>295.5</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1520</td><td>2025-08</td><td>9</td><td>0.4444444444444444</td><td>0.6666666666666666</td><td>0.4444444444444444</td><td>0.4889424944444445</td><td>566.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1530</td><td>2025-06</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>64.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1600</td><td>2025-07</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>207.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1610</td><td>2025-08</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>5054.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1630</td><td>2025-08</td><td>10</td><td>0.3</td><td>0.0</td><td>0.0</td><td>0.49803721300000003</td><td>4524.1</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1640</td><td>2025-08</td><td>9</td><td>0.4444444444444444</td><td>0.0</td><td>0.0</td><td>0.4985851611111111</td><td>4487.111111111111</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1670</td><td>2025-06</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>192.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1670</td><td>2025-07</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>9.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1690</td><td>2025-08</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>16356.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1700</td><td>2025-08</td><td>27</td><td>0.7777777777777778</td><td>0.037037037037037035</td><td>0.18518518518518517</td><td>0.510124747037037</td><td>1378.4074074074074</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1840</td><td>2017-01</td><td>32</td><td>1.53125</td><td>0.65625</td><td>0.1875</td><td>0.508830108125</td><td>9402.4375</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1840</td><td>2017-02</td><td>68</td><td>4.25</td><td>1.1764705882352942</td><td>0.4264705882352941</td><td>0.5258960261764708</td><td>10384.75</td><td>1.0</td><td>0.029411764705882353</td><td>0.0</td></tr><tr><td>1900</td><td>2025-08</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.5</td><td>383.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1930</td><td>2025-08</td><td>14</td><td>0.9285714285714286</td><td>0.07142857142857142</td><td>0.0</td><td>0.5083395764285715</td><td>2300.5</td><td>1.0</td><td>0.0</td><td>0.0</td></tr></tbody></table></div>

# %%
app_review_agg_df.write.mode("overwrite").parquet(
    "s3://steam-dataset-2025-bucket/powerbi/fact_app_level/parquet/"
)

# %%
app_review_agg_df.coalesce(1).write.mode("overwrite").option("header", "true").csv(
    "s3://steam-dataset-2025-bucket/powerbi/fact_app_level/csv/"
)

# %%
app_month_review_agg_df.write.mode("overwrite").parquet(
    "s3://steam-dataset-2025-bucket/powerbi/fact_app_month/parquet/"
)

# %%
app_month_review_agg_df.coalesce(1).write.mode("overwrite").option("header", "true").csv(
    "s3://steam-dataset-2025-bucket/powerbi/fact_app_month/csv/"
)

# %%
bi_reviews_time_df.write.mode("overwrite").parquet(
    "s3://steam-dataset-2025-bucket/powerbi/fact_review_level/parquet/"
)

# %%
bi_reviews_time_df.coalesce(1).write.mode("overwrite").option("header", "true").csv(
    "s3://steam-dataset-2025-bucket/powerbi/fact_review_level/csv/"
)

# %%
from pyspark.sql.functions import lit

app_level_combined = app_review_agg_df \
    .withColumn("review_year_month", lit(None).cast("string")) \
    .withColumn("dataset_type", lit("app_level"))

app_month_combined = app_month_review_agg_df \
    .withColumn("dataset_type", lit("app_month"))

review_level_combined = bi_reviews_time_df \
    .select("appid", "review_year_month") \
    .withColumn("dataset_type", lit("review_level"))

# %%
combined_df = app_level_combined.unionByName(
    app_month_combined, allowMissingColumns=True
).unionByName(
    review_level_combined, allowMissingColumns=True
)

# %%
combined_df.write.mode("overwrite").parquet(
    "s3://steam-dataset-2025-bucket/combined/parquet/"
)

# %%
combined_df.coalesce(1).write.mode("overwrite").option("header", "true").csv(
    "s3://steam-dataset-2025-bucket/combined/csv/"
)

# %%
display(combined_df.count())
# Out:
# 1567104

# %%
display(combined_df.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appid</th><th>total_reviews</th><th>avg_votes_up</th><th>avg_votes_funny</th><th>avg_comment_count</th><th>avg_weighted_vote_score</th><th>avg_playtime_forever</th><th>pct_steam_purchase</th><th>pct_received_for_free</th><th>pct_early_access</th><th>review_year_month</th><th>dataset_type</th><th>monthly_reviews</th></tr></thead><tbody><tr><td>1362650</td><td>17</td><td>1.1764705882352942</td><td>0.0</td><td>0.058823529411764705</td><td>0.5073456358823529</td><td>149.1764705882353</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>525640</td><td>100</td><td>5.26</td><td>0.23</td><td>0.22</td><td>0.5514197209000001</td><td>2874.67</td><td>1.0</td><td>0.01</td><td>0.74</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>962300</td><td>4</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.4953703725</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>617580</td><td>9</td><td>2.0</td><td>0.0</td><td>0.1111111111111111</td><td>0.5171290133333334</td><td>3744.6666666666665</td><td>1.0</td><td>0.1111111111111111</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>1633470</td><td>4</td><td>2.75</td><td>0.25</td><td>0.5</td><td>0.553060665</td><td>60.5</td><td>1.0</td><td>0.25</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>1283960</td><td>100</td><td>2.84</td><td>0.3</td><td>0.09</td><td>0.5295989410999999</td><td>3048.88</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>323250</td><td>19</td><td>2.473684210526316</td><td>0.05263157894736842</td><td>0.0</td><td>0.52567672</td><td>4379.9473684210525</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>265240</td><td>21</td><td>7.714285714285714</td><td>0.0</td><td>0.0</td><td>0.5353623980952382</td><td>319.8095238095238</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>934920</td><td>6</td><td>2.1666666666666665</td><td>0.0</td><td>0.0</td><td>0.5470834466666666</td><td>5134.833333333333</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>1097120</td><td>13</td><td>6.846153846153846</td><td>1.0769230769230769</td><td>0.0</td><td>0.5363296376923076</td><td>19.846153846153847</td><td>1.0</td><td>0.07692307692307693</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>1255390</td><td>13</td><td>8.615384615384615</td><td>2.8461538461538463</td><td>0.23076923076923078</td><td>0.5829185015384615</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>1465450</td><td>7</td><td>2.142857142857143</td><td>0.42857142857142855</td><td>0.2857142857142857</td><td>0.5325933014285714</td><td>17.428571428571427</td><td>1.0</td><td>0.0</td><td>1.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>730615</td><td>6</td><td>2.1666666666666665</td><td>0.0</td><td>0.0</td><td>0.5218942666666667</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>1616050</td><td>11</td><td>2.6363636363636362</td><td>0.0</td><td>0.09090909090909091</td><td>0.5318887881818182</td><td>589.9090909090909</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>677090</td><td>4</td><td>1.25</td><td>0.0</td><td>0.25</td><td>0.529214265</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>1013410</td><td>50</td><td>4.72</td><td>0.6</td><td>0.02</td><td>0.5123871104</td><td>48.08</td><td>1.0</td><td>0.0</td><td>1.0</td><td>null</td><td>app_level</td><td>null</td></tr><tr><td>1036260</td><td>53</td><td>2.660377358490566</td><td>0.20754716981132076</td><td>0.2 ...

# %%
combined_df.columns
# Out:
# ['appid',
#  'total_reviews',
#  'avg_votes_up',
#  'avg_votes_funny',
#  'avg_comment_count',
#  'avg_weighted_vote_score',
#  'avg_playtime_forever',
#  'pct_steam_purchase',
#  'pct_received_for_free',
#  'pct_early_access',
#  'review_year_month',
#  'dataset_type',
#  'monthly_reviews']

# %% [markdown]
# #### Review Level Data

# %%
bi_reviews_time_df.columns
# Out:
# ['appid',
#  'recommendationid',
#  'votes_up',
#  'votes_funny',
#  'comment_count',
#  'weighted_vote_score',
#  'author_playtime_at_review',
#  'author_playtime_forever',
#  'author_playtime_last_two_weeks',
#  'author_num_games_owned',
#  'author_num_reviews',
#  'steam_purchase',
#  'received_for_free',
#  'written_during_early_access',
#  'language',
#  'timestamp_created',
#  'author_playtime_forever_capped',
#  'author_playtime_at_review_capped',
#  'author_playtime_last_two_weeks_capped',
#  'votes_up_capped',
#  'votes_funny_capped',
#  'comment_count_capped',
#  'review_timestamp',
#  'review_date',
#  'review_year',
#  'review_month',
#  'review_year_month']

# %% [markdown]
# #### App level data

# %%
app_month_review_agg_df.columns
# Out:
# ['appid',
#  'review_year_month',
#  'monthly_reviews',
#  'avg_votes_up',
#  'avg_votes_funny',
#  'avg_comment_count',
#  'avg_weighted_vote_score',
#  'avg_playtime_forever',
#  'pct_steam_purchase',
#  'pct_received_for_free',
#  'pct_early_access']

# %%
app_review_agg_df.columns
# Out:
# ['appid',
#  'total_reviews',
#  'avg_votes_up',
#  'avg_votes_funny',
#  'avg_comment_count',
#  'avg_weighted_vote_score',
#  'avg_playtime_forever',
#  'pct_steam_purchase',
#  'pct_received_for_free',
#  'pct_early_access']
